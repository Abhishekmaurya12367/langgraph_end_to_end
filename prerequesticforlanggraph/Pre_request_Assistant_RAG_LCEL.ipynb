# %%
import os

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
LANGCHAIN_API_KEY=os.getenv("LANGCHAIN_API_KEY")
GOOGLE_API_KEY=os.getenv("GOOGLE_API_KEY")
TAVILY_API_KEY=os.getenv("TAVILY_API_KEY")
LANGCHAIN_PROJECT=os.getenv("LANGCHAIN_PROJECT")
SERPER_API_KEY=os.getenv("SERPER_API_KEY")
GROQ_API_KEY=os.getenv("GROQ_API_KEY")

# %%
os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
os.environ["TAVILY_API_KEY"] = TAVILY_API_KEY
os.environ["GROQ_API_KEY"] = GROQ_API_KEY
os.environ["LANGCHAIN_API_KEY"] = LANGCHAIN_API_KEY
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"
os.environ["LANGCHAIN_PROJECT"] = LANGCHAIN_PROJECT

# %%
from langchain_google_genai import GoogleGenerativeEmbedding 
embedding =GoogleGenerativeEmbedding(model="model/embedding-001")
from langchain_google_genai import ChatGoogleGenerativeAI
llm=ChatGoogleGenerativeAI(model="gemini-01-pro")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from langchain_google_genai import GoogleGenerativeEmbedding
#       2 embedding =GoogleGenerativeEmbedding(model="model/embedding-001")
#       3 from langchain_google_genai import ChatGoogleGenerativeAI
#       4 llm=ChatGoogleGenerativeAI(model="gemini-01-pro")
#
# ImportError: cannot import name 'GoogleGenerativeEmbedding' from 'langchain_google_genai' (d:\abhishek\langgraph_end_to_end\venv\Lib\site-packages\langchain_google_genai\__init__.py)

# %%
from langchain_groq import ChatGroq
import os
llm=ChatGroq(model_name="Gemma2-9b-It")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from langchain_groq import ChatGroq
#       2 import os
#       3 llm=ChatGroq(model_name="Gemma2-9b-It")
#
# ModuleNotFoundError: No module named 'langchain_groq'
