# %% [markdown]
# i am going to make the workflow of the graph that graph

# %%
def function1(input1):
    return input1+"hello how are you please tell me about you somethings "

def function2(input2):
    return input2+"hey i am the good can you things about me if yes then your the legend bro"

# %%
from langgraph.graph import Graph

# %%
workflow1=graph()

# %%
workflow1.add_node("function1",function1)
